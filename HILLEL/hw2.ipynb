# %%
#ДЗ 2.1

a= int(input())
a4=a % 10
a3=a % 100 // 10
a2=a % 1000 // 100
a1=a // 1000
print (a1)
print (a2)
print (a3)
print (a4)
# Out:
# 1
# 0
# 5
# 0

# %%
#ДЗ 2.1

a= int(input())
a4 = a % 10
a3 = (a // 10) % 10
a2 = (a // 100) % 10
a1 = (a // 1000) % 10
print (a1)
print (a2)
print (a3)
print (a4)
# Out:
# 1
# 0
# 5
# 0

# %%
#ДЗ 2.2

a= int(input())
a5=a % 10
a4=a % 100 // 10
a3=a % 1000 // 100
a2=a % 10000 // 1000
a1=a // 10000
print (a5, a4, a3, a2, a1)
# Out:
# 5 4 3 2 1

# %%
#ДЗ 2.2

a= int(input())
a5 = a % 10
a4 = (a // 10) % 10
a3 = (a // 100) % 10
a2 = (a // 1000) % 10
a1 = a // 10000
print( a5 * 10000 + a4 * 1000 + a3 * 100 + a2 * 10 + a1)
# Out:
# 56789
